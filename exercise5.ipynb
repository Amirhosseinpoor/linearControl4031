# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirhosseinpoor/linearControl4031/blob/main/exercise5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scipy matplotlib numpy control

import numpy as np
import matplotlib.pyplot as plt
from control import tf, bode, pade

g = tf([5, 5], [5, 1, 0])
s = tf('s')
num, den = pade(2, 1)
delay = tf(num, den)
G = g * delay
plt.figure()
bode(G, dB=True, Hz=False, deg=True)
plt.show()
