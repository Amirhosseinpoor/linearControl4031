# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirhosseinpoor/linearControl4031/blob/main/googlecolab/hw4/exercise4_q4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install control matplotlib numpy

from control import tf, zeros, poles, dcgain, nyquist
import matplotlib.pyplot as plt
import numpy as np

numerator = np.convolve([1, 1], np.convolve([1, 2], np.convolve([1, 3], [1, 4])))
denominator = np.convolve([1, 0, 0, 0], [1, 100])

h = tf(-1 * numerator, denominator)

zeros = zeros(h)
poles = poles(h)
gain = dcgain(h)

print("Zeros:", zeros)
print("Poles:", poles)
print("Gain:", gain)

plt.figure()
nyquist(h)
plt.title('Nyquist Plot')
plt.grid(True)
plt.show()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.6/549.6 kB 5.9 MB/s eta 0:00:00
# ...
# Zeros: [-4.+0.j -3.+0.j -2.+0.j -1.+0.j]
# Poles: [-100.+0.j    0.+0.j    0.+0.j    0.+0.j]
# Gain: -inf
# /usr/local/lib/python3.11/dist-packages/control/freqplot.py:1454: UserWarning: number of encirclements was a non-integer value; this can happen is contour is not closed, possibly based on a frequency range that does not include zero.
#   warnings.warn(
