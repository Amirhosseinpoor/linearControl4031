# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirhosseinpoor/linearControl4031/blob/main/googlecolab/hw2/exercise2_q3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install control matplotlib

from control import tf, step_response, step_info
import matplotlib.pyplot as plt

K = 8.41
T = tf([K], [1, 4, K])

time, response = step_response(T)

plt.figure()
plt.plot(time, response)
plt.title('Step Response of the System for K = 8.41')
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

info = step_info(T)
print(info)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.6/549.6 kB 21.7 MB/s eta 0:00:00
# ...
# {'RiseTime': 0.7326407114071962, 'SettlingTime': 2.0932591754491323, 'SettlingMin': 0.9068044798084374, 'SettlingMax': 1.0501836596528418, 'Overshoot': 5.018365965284177, 'Undershoot': 0, 'Peak': 1.0501836596528418, 'PeakTime': 1.5001690757385449, 'SteadyStateValue': 1.0}
