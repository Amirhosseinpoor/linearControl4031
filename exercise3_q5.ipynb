# %% [markdown]
# <a href="https://colab.research.google.com/github/Amirhosseinpoor/linearControl4031/blob/main/exercise3_q5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install control matplotlib

from control import tf, step_response, step_info, poles, zeros, dcgain
import matplotlib.pyplot as plt

G = tf([5, 10], [1, 4, 5])
T = tf([5, 10], [1, 9, 15])

print('System:')
poles = poles(G)
zeros = zeros(G)
print("Poles:", poles)
print("Zeros:", zeros)

response, time = step_response(T)

plt.figure()
plt.plot(time, response, '-', linewidth=0.5)
plt.grid(True)
plt.title('Step Response')
plt.xlabel('Time (seconds)')
plt.ylabel('Response')
plt.show()

info = step_info(T)
print('Step Response Characteristics:')
print(info)

k = dcgain(G)
error_steady_state = 1 / (1 + k)
print(f'Steady-State Error: {error_steady_state}')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.6/549.6 kB 7.3 MB/s eta 0:00:00
# ...
# System:
# Poles: [-2.+1.j -2.-1.j]
# Zeros: [-2.+0.j]
# Step Response Characteristics:
# {'RiseTime': 0.264010046854345, 'SettlingTime': 0.8529555359909606, 'SettlingMin': 0.6100580098037924, 'SettlingMax': 0.6820253687362408, 'Overshoot': 2.303805310436119, 'Undershoot': 0, 'Peak': 0.6820253687362408, 'PeakTime': 0.6904878148498252, 'SteadyStateValue': 0.6666666666666666}
# Steady-State Error: 0.3333333333333333
